# %% [markdown]
# # Testing Markdown..

# %% [markdown]
# # Jupyter Notebook Demo
#
# This notebook demonstrates basic `.ipynb` capabilities.

# %%
x = 10
y = 5
x + y
# Out:
# 20

# %%
x * 3

# %% [markdown]
# ## Tables with Pandas

# %%
import pandas as pd
df = pd.DataFrame({'n': [1,2,3], 'square': [1,4,9]})
df
# Out:
#    n  square
# 0  1       1
# 1  2       4
# 2  3       9

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3], [1,4,9])
plt.title('Squares')
plt.show()

# %%
import os
os.getcwd()
# Out:
# '/home/jsalmassi/my_projects/programmingbitcoin'

# %%
os.getcwd()
# Out:
# '/home/jsalmassi/my_projects/programmingbitcoin'

# %%
from IPython.display import Image, display
display(Image(filename="my_owl.jpeg"))
display.title = "My Sweet little Owl"

# %% [markdown]
# Sweet little Owl

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate image data
data = np.random.rand(10, 10)

plt.imshow(data, cmap="viridis")
plt.colorbar(label="Value")
plt.title("Random Image Example")
plt.show()
